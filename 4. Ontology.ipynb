# %% [markdown]
# # Data Curation Final Project
#
# ## Ontology
#
# We're now missing a proper VKG Ontology for this domain, that we will use for future mapping. While ontologies are supposed to represent the objects themselves, since we have already have a highly normalized database it would be unwise to not use it as inspiration for our ontology.
#
# ![Database diagram.png](<attachment:Database diagram.png>)

# %% [markdown]
# #### Municipalities
#
# Let's start with the classes that refer to the Municipalities table and its lookup tables.
#
#
# > Geographic Unit
# >
# >> Municipality
# >>
# >> Provincial District
# >>
# >> Health District
# >>
# >> Health Region
# >>
#
# Should be their own classes.
#
# We can have
# > name (with language)
# >
# > has identifier
# >
# >> zip code (subclass of 'has identifier')
# >>
# >> istat code (subclass of 'has identifier')
# >>
# >> belfiore code (subclass of 'has identifier')
# >
# > belongs to geographic or administrative region
# >
# > area
# >
# > shape
# >
#
# As properties.

# %% [markdown]
# #### Hazard Zones
#
# We can have the following classes
#
# > Hazard Zone
# >
# >> Avalanche Zone
# >>
# >> Landslide Zone
# >
# > Process
# >
# > Study level
# >
# > Danger level
# >
# > > Avalanche danger level
# > >
#
# Some of these classes will already come with instances in the ontology:
#
#
# > Process
# >
# > > Landslide
# > >
# > > Collapse
# > >
# > > Sliding
# > >
# > > Subsidence
# > >
# > > Slope Flow
# > >
# > > Avalanche
# > >
# > > Snow Slab Avalanche
# > >
# > > Powder Snow Avalanche
# > >
# > > Surface Avalanche
# > >
# > > Unknown process
# >
# > Study level
# >
# > > High study level
# > >
# > > Medium study level
# > >
# > > Low study level
# > >
# > > Unknown study level
# > >
# >
# > Danger level
# >
# > > Avalanche danger level
# > >
# > > > Very high avalanche danger
# > > >
# > > > High avalanche danger
# > > >
# > > > Medium avalanche danger
# > > >
# > > > Examined and not in danger of avalanches
# > > >
# > > Landslide danger level
# > >
# > > > Very high landslide danger
# > > >
# > > > High landslide danger
# > > >
# > > > Medium landslide danger
# > > >
# > > > Examined and not in danger of landslides
# > > >
#
#
# We would only need new datatype properties for x_label and y_label, but this isn't really interesting for our application.
#
# For object properties, we can have
#
# > Has process level
# >
# > Has study level
# >
# > Has danger level
# >
# > Is located in municipality

# %% [markdown]
# #### Road segments
#
# For road segments, we need the following classes:
#
# > Road segment
# > >
# >> Bridge
# >>
# >> Tunnel
# >>
# > Route Reference
# >
# > Road Segment Conection Point
#
# We'll need new properties too.
# > has identifier
# >> has osmid
# >
# > belongsToRef
# >
# > comesFromPoint
# >
# > goesToPoint
# >
# > intersectsHazardZone
