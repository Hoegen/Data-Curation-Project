# %% [markdown]
# ## Project Status Update: VKG Mapping with Ontop
#
# ### Data Profiling Part
# - [x] Export the datasets of interest and perform Elementary Data Analysis (EDA)
# - [x] Design one or more relational databases
# - [x] **Document the results of data profiling and schema design choices in the final project documentation**
#
# ### Data Preparation and Integration Part
# - [x] Consider the relational database(s) designed for the Data Profiling module, including relevant constraints
# - [x] **Ontology design:** 10+ classes and corresponding object/data properties (now complete)
# - [x] **Document the ontology and schema using graphical notation** (e.g., UML, ER, or ontology diagram)
# - [x] **Represent the ontology in Protégé**
# - [ ] **Design VKG mappings** to connect the ontology to the database using Ontop Plugin for Protégé (or Ontopic Suite)
# - [ ] **Develop an application** (e.g., in Java or Python) that uses Ontop as a SPARQL endpoint to query the database through the ontology, extracting domain-relevant information
#
# ---
#
# ### Summary of Current Status
# - **EDA and Database Design:** Complete
# - **Ontology:** Complete
# - **Database Implementation:** Complete
# - **Documentation:** Missing for application and mappings
# - **Graphical Representation:** Complete
# - **VKG Mappings (Ontop):** Missing
# - **Application (SPARQL queries):** Missing
#
# ---
#
# **Next Steps:**
# 1. Document data profiling and schema design choices.
# 2. Create a graphical representation of the ontology.
# 3. Import and refine the ontology in Protégé.
# 4. Design and test VKG mappings in Ontop.
# 5. Develop and test the application with SPARQL queries.
#
# Let me know if you want a checklist, timeline, or help with any specific next step!
